# %%
from mel import compute_mel_spectrogram, plot_mel_spectrogram, frames_to_video, get_frame_at_timestamp
import os
import cv2
import matplotlib.pyplot as plt

# %%
root = '/home/punygod_admin/SoundSense/soundsense/data/seventysix/data/17/'
frames_path = os.path.join(root, 'video')
audio_path = os.path.join(root, 'processed_audio.wav')

# %%
mel_spectrogram, sr = compute_mel_spectrogram(audio_path)
plot_mel_spectrogram(mel_spectrogram, sr, (15,3))

# %%
t = 17

fps = 10
# video_path = 'video.mp4'
# frames_to_video(frames_path, video_path)
# frame = get_frame_at_timestamp(video_path, t)
frames = os.listdir(frames_path)
frames.sort()
path_t = frames[int(t*fps)]
frame = cv2.imread(os.path.join(frames_path, path_t))
if frame is not None:
    plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    plt.axis('off')
